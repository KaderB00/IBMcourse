# %%
Python 3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)] on win32
Type "help", "copyright", "credits" or "license" for more information.
>>>
>>> print('hello')
hello
>>> name = print('hello world')
hello world
>>> name = 5
>>> name = hello world
  File "<stdin>", line 1
    name = hello world
                 ^
SyntaxError: invalid syntax
>>> name = print('hello world')
hello world
>>> name[2]
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
TypeError: 'NoneType' object is not subscriptable
>>> name[3]:
  File "<stdin>", line 1
    name[3]:
            ^
SyntaxError: invalid syntax
>>> name = 'hello world'
>>> name[2]:
  File "<stdin>", line 1
    name[2]:
            ^
SyntaxError: invalid syntax
>>> name[2]: e
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
NameError: name 'e' is not defined
>>> name= 'hellow world'
>>> name[2]:
  File "<stdin>", line 1
    name[2]:
            ^
SyntaxError: invalid syntax
>>> name[2]
'l'
>>> Name= 'hello my friend'
>>> Name[3]
'l'
>>> Name[1]
'e'
>>> Name[0]
'h'
>>> Name[-1]
'd'
>>> Name[0:2]
'he'
>>> Name[0:3]
'hel'
>>> Name[4:7]
'o m'
>>> Name[::2]
'hlom red'
>>> Name[0:6:3]
'hl'
>>> Name[0:7:3]
'hlm'
>>> len(Name)
15
>>> phrase = Name + 'what is your name'
>>> phrase
'hello my friendwhat is your name'
>>> 3 * phrase
'hello my friendwhat is your namehello my friendwhat is your namehello my friendwhat is your name'
>>> name /n phrase
  File "<stdin>", line 1
    name /n phrase
            ^
SyntaxError: invalid syntax
>>> name \n phrase
  File "<stdin>", line 1
    name \n phrase
                 ^
SyntaxError: unexpected character after line continuation character
>>> phraes
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
NameError: name 'phraes' is not defined
>>> phrase
'hello my friendwhat is your name'
>>> print('hi \n phrase')
hi
 phrase
>>> print (name \n phrase)
  File "<stdin>", line 1
    print (name \n phrase)
                         ^
SyntaxError: unexpected character after line continuation character
>>> print(name \n phrase)
  File "<stdin>", line 1
    print(name \n phrase)
                        ^
SyntaxError: unexpected character after line continuation character
>>> name
'hellow world'
>>> phrase
'hello my friendwhat is your name'
>>> name \n phrase
  File "<stdin>", line 1
    name \n phrase
                 ^
SyntaxError: unexpected character after line continuation character
>>> print('hi \n hi, how are you')
hi
 hi, how are you
>>> print('hi \nhi how are you')
hi
hi how are you
>>> print('hi \t OMG ITS YOU')
hi       OMG ITS YOU
>>> upper case = A.name()
  File "<stdin>", line 1
    upper case = A.name()
          ^
SyntaxError: invalid syntax
>>> A.name
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
NameError: name 'A' is not defined
>>> B=name.upper()
>>> B
'HELLOW WORLD'
>>> C = phrase.upper()
>>> C
'HELLO MY FRIENDWHAT IS YOUR NAME'
>>> D=B.lower()
>>> D
'hellow world'
>>> E = D.replace('hellow', 'hello')
>>> E
'hello world'
>>> D = D.replace('hellow', 'hello')
>>> D
'hello world'
>>> D.find('wo')
6
>>> D.find('me')
-1
>>>
# Out:
#   File "<ipython-input-1-e3116b05e691>", line 1
#     Python 3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)] on win32
#              ^
# SyntaxError: invalid syntax

# %%
#the code above was completed on python whilst I was watching the course video on strings. Just there for reference :)

# %%
#Since I completed most of the coding practise whilst I was watching the video this section
#is merely a recap so there wont be much coding

# %%
# Write your code below and press Shift+Enter to execute

e = 'clocrkr1e1c1t'
print(e[0:13:2]) #this was my answer but there is an easier way check next
print(e[::2])
# Out:
# correct
# correct
